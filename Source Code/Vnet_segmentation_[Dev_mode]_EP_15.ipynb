# %% [markdown]
# ### **Firman Maulana (190411100195)**
# ### **Teknik Informatika**

# %% [markdown]
# ### **information about the system's block devices**
#
# Here is a brief explanation of each column in the output:
# *   **KNAME:** The kernel device name, which is used to identify the device in the Linux kernel.
# *   **TYPE:** The type of block device, which can be disk, part (partition), or loop (loopback device).
# *   **SIZE:** The size of the block device in bytes.
# *   **MODEL:** The model name or identifier of the device, which can be useful for identifying the device's manufacturer or model number.

# %%
! lsblk -io KNAME,TYPE,SIZE,MODEL #disk
# Out:
# KNAME TYPE  SIZE MODEL
# loop0 loop   80G
# sda   disk   80G PersistentDisk
# sda1  part 75.8G
# sda2  part   16M
# sda3  part    2G
# sda4  part   16M
# sda5  part    2G
# sda6  part  512B
# sda7  part  512B
# sda8  part   16M
# sda9  part  512B
# sda10 part  512B
# sda11 part    8M
# sda12 part   32M

# %% [markdown]
# #### **detailed information about the system's hardware configuration.**

# %%
_ = ! apt install lshw
! lshw
# Out:
# 6ebd16485d47
#     description: Computer
#     width: 64 bits
#     capabilities: smp vsyscall32
#   *-core
#        description: Motherboard
#        physical id: 0
#      *-memory
#           description: System memory
#           physical id: 0
#           size: 12GiB
#      *-cpu
#           product: Intel(R) Xeon(R) CPU @ 2.00GHz
#           vendor: Intel Corp.
#           physical id: 1
#           bus info: cpu@0
#           version: 6.85.3
#           width: 64 bits
#           capabilities: fpu fpu_exception wp vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp x86-64 constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
#           configuration: microcode=4294967295
#      *-pci
#           description: Host bridge
#           product: 440FX - 82441FX PMC [Natoma]
#           vendor: Intel Corporation
#           physical id: 100
#           bus info: pci@0000:00:00.0
#           version: 02
#           width: 32 bits
#           clock: 33MHz
#         *-isa
#              description: ISA bridge
#              product: 82371AB/EB/MB PIIX4 ISA
#              vendor: Intel Corporation
#              physical id: 1
#              bus info: pci@0000:00:01.0
#              version: 03
#              width: 32 bits
#              clock: 33MHz
#              capabilities: isa bus_master
#              configuration: latency=0
#            *-pnp00:00
#                 product: PnP device PNP0b00
#                 physical id: 0
#                 capabilities: pnp
#                 configuration: driver=rtc_cmos
#            *-pnp00:01
#                 product: PnP device PNP0303
#                 physical id: 1
#                 capabilities: pnp
#                 configuration: driver=i8042 kbd
#            *-pnp00:02
#                 product: PnP device PNP0f13
#                 physical id: 2
#                 capabilities: pnp
#                 configuration: driver=i8042 aux
#            *-pnp00:03
#                 product: PnP device PNP0501
#                 physical id: 3
#                 capabilities: pnp
#                 configuration: driver=serial
#            *-pnp00:04
#                 product: PnP device PNP0501
#                 physical id: 4
#                 capabilities: pnp
#                 configuration: driver=serial
#            *-pnp00:05
#                 product: PnP device PNP0501
#                 physical id: 5
#                 capabilities: pnp
#                 configuration: driver=serial
#            *-pnp00:06
#                 product: PnP device PNP0501
#                 physical id: 6
#                 capabilities: pnp
#                 configuration: driver=serial
#         *-bridge UNCLAIMED
#              description: Bridge
#              product: 82371AB/EB/MB PIIX4 ACPI
#              vendor: Intel Corporation
#              physical id: 1.3
#              bus info: pci@0000:00:01.3
#              version: 03
#              width: 32 bits
#              clock: 33MHz
#              capabilities: bridge bus_master
#              configuration: latency=0
#         *-generic:0
#              description: Non-VGA unclassified device
#              product: Virtio SCSI
#              vendor: Red Hat, Inc.
#              physical id: 3
#              bus info: pci@0000:00:03.0
#              version: 00
#              width: 32 bits
#              clock: 33MHz
#              capabilities: msix bus_master cap_list
#              configuration: driver=virtio-pci latency=0
#              resources: irq:11 ioport:c040(size=64) memory:c1001000-c100107f
#            *-virtio0 UNCLAIMED
#                 description: Virtual I/O device
#                 physical id: 0
#                 bus info: virtio@0
#                 configuration: driver=virtio_scsi
#         *-display
#              description: 3D controller
#              product: TU104GL [Tesla T4]
#              vendor: NVIDIA Corporation
#              physical id: 4
#              bus info: pci@0000:00:04.0
#              version: a1
#              width: 64 bits
#              clock: 33MHz
#              capabilities: msix pm bus_master cap_list
#              configuration: driver=nvidia latency=0
#              resources: iomemory:30-2f iomemory:30-2f irq:11 memory:c0000000-c0ffffff memory:380000000-38fffffff memory:390000000-391ffffff
#         *-network
#              description: Ethernet controller
#              product: Virtio network device
#              vendor: Red Hat, Inc.
#              physical id: 5
#              bus info: pci@0000:00:05.0
#              version: 00
#              width: 32 bits
#              clock: 33MHz
#              capabilities: msix bus_master cap_list
#              configuration: driver=virtio-pci latency=0
#              resources: irq:10 ioport:c000(size=64) memory:c1000000-c100007f
#            *-virtio1 UNCLAIMED
#                 description: Virtual I/O device
#                 physical id: 0
#                 bus info: virtio@1
#                 configuration: driver=virtio_net
#         *-generic:1
#              description: Unclassified device
#              product: Virtio RNG
#              vendor: Red Hat, Inc.
#              physical id: 6
#              bus info: pci@0000:00:06.0
#              version: 00
#              width: 32 bits
#              clock: 33MHz
#              capabilities: msix bus_master cap_list
#              configuration: driver=virtio-pci latency=0
#              resources: irq:10 ioport:c080(size=32) memory:c1002000-c100203f
#            *-virtio2 UNCLAIMED
#                 description: Virtual I/O device
#                 physical id: 0
#                 bus info: virtio@2
#                 configuration: driver=virtio_rng
#   *-input:0
#        product: Power Button
#        physical id: 1
#        logical name: input0
#        logical name: event0
#        capabilities: platform
#   *-input:1
#        product: Sleep Button
#        physical id: 2
#        logical name: input1
#        logical name: event1
#        capabilities: platform
#   *-input:2
#        product: AT Translated Set 2 keyboard
#        physical id: 3
#        logical name: input2
#        logical name: event2
#        capabilities: i8042

# %% [markdown]
# ##### **information about GPU**

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Jan  9 18:39:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### **mounts the Google Drive to a Colab notebook**
# *to allows access to files and folders stored in the drive*

# %%
from google.colab import drive
drive.mount('/content/drive/')
# root_path = 'gdrive/My Drive/your_project_folder/'  #change dir to your project folder
# Out:
# Mounted at /content/drive/

# %%
# Full Tensorflow
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
from tensorflow.keras.layers import Input, add, Conv2D, PReLU, MaxPool2D, Concatenate, Dropout, Conv2DTranspose, MaxPooling2D, UpSampling2D, BatchNormalization, Activation
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import load_img, array_to_img, img_to_array
from tensorflow.keras.models import Sequential, Model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# TensorFlow version: 2.15.0

# %% [markdown]
# ### **Dataset preparation**

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/anasmohammedtahir/covidqu
# <br>
# <br>
# Journal Method: https://arxiv.org/abs/1606.04797
# <br>
# <br>
# Inspiration Code: https://github.com/NVIDIA/DeepLearningExamples/tree/master/TensorFlow/Segmentation/VNet

# %% [markdown]
# ##### **Data collection**
# *Downoad data from kaggle.*

# %%
# Install Writer Excel
_ = ! pip install xlsxwriter

# %%
EXCEL_FILENAME = "./Shuffled_COVID_QU_Ex_Dataset/Split_Data_COVID_QU_Paths.xlsx"

# %%
# # Get data from Kaggle
_ = ! git clone https://github.com/achmadbauravindah/ravin_kaggle_credential.git # get credential from kaggle
_ = ! pip install kaggle # install kaggle on device
_ = ! mkdir ~/.kaggle # make hidden folder .kaggle to configure credential
_ = ! cp ravin_kaggle_credential/kaggle.json ~/.kaggle/ # copy credential from github to .kaggle folder
_ = ! chmod 600 ~/.kaggle/kaggle.json # change access
_ = ! kaggle datasets download achmadbauravindah/covid-qu-dataset-1500-shuffled # which dataset to download
_ = ! unzip covid-qu-dataset-1500-shuffled # unzip if data zipped

# %% [markdown]
# ##### **Sample Image and Mask CXR**

# %%
import cv2

sample_image = pd.read_excel(EXCEL_FILENAME)['images_path'][0]
sample_mask = pd.read_excel(EXCEL_FILENAME)['masks_path'][0]

print("Sample Image CXR")
print("Images Path: {}".format(sample_image))

# Load the image and mask in grayscale mode
image = cv2.imread(sample_image, cv2.IMREAD_GRAYSCALE)
mask = cv2.imread(sample_mask, cv2.IMREAD_GRAYSCALE)

fig, axes = plt.subplots(1, 2)
_ = axes[0].imshow(np.load(sample_image).reshape(256, 256), cmap='gray')
_ = axes[1].imshow(np.load(sample_mask).reshape(256, 256), cmap='gray')

plt.show()
# Out:
# Sample Image CXR
# Images Path: Shuffled_COVID_QU_Ex_Dataset/Covid-19/npy_images/CXR_Images_41.npy

# %% [markdown]
# # **Conv Block**

# %%
! pip install keras_unet_collection
# Out:
# Collecting keras_unet_collection
#   Downloading keras_unet_collection-0.1.13-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: keras_unet_collection
# Successfully installed keras_unet_collection-0.1.13

# %%
from __future__ import absolute_import

from keras_unet_collection.layer_utils import *
from keras_unet_collection.activations import GELU, Snake

from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model


def vnet_left(X, channel, res_num, activation='ReLU', pool=True, batch_norm=False, name='left'):
    '''
    The encoder block of 2-d V-net.

    vnet_left(X, channel, res_num, activation='ReLU', pool=True, batch_norm=False, name='left')

    Input
    ----------
        X: input tensor.
        channel: number of convolution filters.
        res_num: number of convolutional layers within the residual path.
        activation: one of the `tensorflow.keras.layers` interface, e.g., 'ReLU'.
        pool: True or 'max' for MaxPooling2D.
              'ave' for AveragePooling2D.
              False for strided conv + batch norm + activation.
        batch_norm: True for batch normalization, False otherwise.
        name: name of the created keras layers.

    Output
    ----------
        X: output tensor.

    '''

    # Set the pool size for downsampling
    pool_size = 2

    # Encode the input with convolutional layers
    X = encode_layer(X, channel, pool_size, pool, activation=activation,
                     batch_norm=batch_norm, name='{}_encode'.format(name))

    # Apply additional convolutional layer before downsampling if pooling is enabled
    if pool is not False:
        X = CONV_stack(X, channel, kernel_size=3, stack_num=1, dilation_rate=1,
                       activation=activation, batch_norm=batch_norm, name='{}_pre_conv'.format(name))

    # Apply residual convolutional layers
    X = Res_CONV_stack(X, X, channel, res_num=res_num, activation=activation,
                       batch_norm=batch_norm, name='{}_res_conv'.format(name))

    # Return the output
    return X

def vnet_right(X, X_list, channel, res_num, activation='ReLU', unpool=True, batch_norm=False, name='right'):
    '''
    The decoder block of 2-d V-net.

    vnet_right(X, X_list, channel, res_num, activation='ReLU', unpool=True, batch_norm=False, name='right')

    Input
    ----------
        X: input tensor.
        X_list: a list of other tensors that connected to the input tensor.
        channel: number of convolution filters.
        stack_num: number of convolutional layers.
        res_num: number of convolutional layers within the residual path.
        activation: one of the `tensorflow.keras.layers` interface, e.g., 'ReLU'.
        unpool: True or 'bilinear' for Upsampling2D with bilinear interpolation.
                'nearest' for Upsampling2D with nearest interpolation.
                False for Conv2DTranspose + batch norm + activation.
        batch_norm: True for batch normalization, False otherwise.
        name: name of the created keras layers.

    Output
    ----------
        X: output tensor.

    '''
    # Set the pool size for upsampling
    pool_size = 2

    # Decode the input with deconvolutional layers
    X = decode_layer(X, channel, pool_size, unpool,
                     activation=activation, batch_norm=batch_norm, name='{}_decode'.format(name))

    # Save the current state of X (skip connection)
    X_skip = X

    # Concatenate the decoded feature map with the corresponding feature maps from the left side
    X = concatenate([X,]+X_list, axis=-1, name='{}_concat'.format(name))

    # Apply residual convolutional layers
    X = Res_CONV_stack(X, X_skip, channel, res_num, activation=activation,
                       batch_norm=batch_norm, name='{}_res_conv'.format(name))

    # Return the output
    return X

def vnet_2d_base(input_tensor, filter_num, res_num_ini=1, res_num_max=3,
                 activation='ReLU', batch_norm=False, pool=True, unpool=True, name='vnet'):
    '''
    The base of 2-d V-net.

    vnet_2d_base(input_tensor, filter_num, res_num_ini=1, res_num_max=3,
                 activation='ReLU', batch_norm=False, pool=True, unpool=True, name='vnet')

    Input
    ----------
        input_tensor: the input tensor of the base, e.g., `keras.layers.Inpyt((None, None, 3))`.
        filter_num: a list that defines the number of filters for each \
                    down- and upsampling levels. e.g., `[64, 128, 256, 512]`.
                    The depth is expected as `len(filter_num)`.
        res_num_ini: number of convolutional layers of the first first residual block (before downsampling).
        res_num_max: the max number of convolutional layers within a residual block.
        activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interfaces, e.g., 'ReLU'.
        batch_norm: True for batch normalization.
        pool: True or 'max' for MaxPooling2D.
              'ave' for AveragePooling2D.
              False for strided conv + batch norm + activation.
        unpool: True or 'bilinear' for Upsampling2D with bilinear interpolation.
                'nearest' for Upsampling2D with nearest interpolation.
                False for Conv2DTranspose + batch norm + activation.
        name: prefix of the created keras layers.

    Output
    ----------
        X: output tensor.

    * This is a modified version of V-net for 2-d inputw.
    * The original work supports `pool=False` only.
      If pool is True, 'max', or 'ave', an additional conv2d layer will be applied.
    * All the 5-by-5 convolutional kernels are changed (and fixed) to 3-by-3.

    '''
    # Get the depth of the network based on the number of filter levels
    depth_ = len(filter_num)

    # determine the number of res conv layers in each down- and upsampling level
    res_num_list = []
    for i in range(depth_):
        temp_num = res_num_ini + i
        if temp_num > res_num_max:
            temp_num = res_num_max
        res_num_list.append(temp_num)

    # List to store skip connections
    X_skip = []

    # initial conv layer
    X = input_tensor
    X = CONV_stack(X, filter_num[0], kernel_size=3, stack_num=1, dilation_rate=1,
                   activation=activation, batch_norm=batch_norm, name='{}_input_conv'.format(name))

    # Initial residual convolutional layer
    X = Res_CONV_stack(X, X, filter_num[0], res_num=res_num_list[0], activation=activation,
                 batch_norm=batch_norm, name='{}_down_0'.format(name))
    X_skip.append(X)

     # Downsampling levels
    for i, f in enumerate(filter_num[1:]):
        X = vnet_left(X, f, res_num=res_num_list[i+1], activation=activation, pool=pool,
                      batch_norm=batch_norm, name='{}_down_{}'.format(name, i+1))

        X_skip.append(X)

    # Reverse the order of skip connections, filter numbers, and residual numbers for upsampling
    X_skip = X_skip[:-1][::-1]
    filter_num = filter_num[:-1][::-1]
    res_num_list = res_num_list[:-1][::-1]

    # Upsampling levels
    for i, f in enumerate(filter_num):
        X = vnet_right(X, [X_skip[i],], f, res_num=res_num_list[i],
                       activation=activation, unpool=unpool, batch_norm=batch_norm, name='{}_up_{}'.format(name, i))

    # Return the final output
    return X


def vnet_2d(input_size, filter_num, n_labels,
            res_num_ini=1, res_num_max=3,
            activation='ReLU', output_activation='Softmax',
            batch_norm=False, pool=True, unpool=True, name='vnet'):
    '''
    vnet 2d

    vnet_2d(input_size, filter_num, n_labels,
            res_num_ini=1, res_num_max=3,
            activation='ReLU', output_activation='Softmax',
            batch_norm=False, pool=True, unpool=True, name='vnet')

    Input
    ----------
        input_size: the size/shape of network input, e.g., `(128, 128, 3)`.
        filter_num: a list that defines the number of filters for each \
                    down- and upsampling levels. e.g., `[64, 128, 256, 512]`.
                    The depth is expected as `len(filter_num)`.
        n_labels: number of output labels.
        res_num_ini: number of convolutional layers of the first first residual block (before downsampling).
        res_num_max: the max number of convolutional layers within a residual block.
        activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interfaces, e.g., 'ReLU'.
        output_activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interface or 'Sigmoid'.
                           Default option is 'Softmax'.
                           if None is received, then linear activation is applied.
        batch_norm: True for batch normalization.
        pool: True or 'max' for MaxPooling2D.
              'ave' for AveragePooling2D.
              False for strided conv + batch norm + activation.
        unpool: True or 'bilinear' for Upsampling2D with bilinear interpolation.
                'nearest' for Upsampling2D with nearest interpolation.
                False for Conv2DTranspose + batch norm + activation.
        name: prefix of the created keras layers.

    Output
    ----------
        model: a keras model.

    * This is a modified version of V-net for 2-d inputw.
    * The original work supports `pool=False` only.
      If pool is True, 'max', or 'ave', an additional conv2d layer will be applied.
    * All the 5-by-5 convolutional kernels are changed (and fixed) to 3-by-3.
    '''

    # Create input layer
    IN = Input(input_size)
    X = IN

    # Base (Core) of the V-Net
    X = vnet_2d_base(X, filter_num, res_num_ini=res_num_ini, res_num_max= res_num_max,
                     activation=activation, batch_norm=batch_norm, pool=pool, unpool=unpool, name=name)
    # Output layer
    OUT = CONV_output(X, n_labels, kernel_size=1, activation=output_activation, name='{}_output'.format(name))

    # Create functional API model
    model = Model(inputs=[IN,], outputs=[OUT,], name='{}_model'.format(name))

    # Return the model
    return model

# %% [markdown]
# ### **DSC  & IoU**

# %%
def dice_coef(y_true, y_pred):
   # Flatten the true and predicted masks
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)

    # Calculate intersection: sum of element-wise product of flattened masks
    # |y_true| ∩ |y_pred|, Kenapa kok dikali setelah itu di sum? Karena BG nilainya 0, jadi yang diambil adalah hanya hasil segmentasi yang nilainya lebih dari 0
    intersection = K.sum(K.abs(y_true_flat * y_pred_flat))

    # Calculate union: sum of elements in both flattened masks
    # |y_true| + |y_pred|
    union = K.sum(y_true_flat) + K.sum(y_pred_flat)

    # Calculate Dice coefficient: (2 * intersection) / (union + 0.0001)
    # 0.0001 untuk mencegah nilai pembaginya 0
    dice = (2. * intersection + 0.0001) / (union + 0.0001)
    return dice

def iou(y_true, y_pred):
    # Flatten the true and predicted masks
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)

    # Calculate intersection: sum of element-wise product of flattened masks
    intersection = K.sum(K.abs(y_true_flat * y_pred_flat))

    # Calculate union: sum of elements in both flattened masks, subtract intersection
    union = K.sum(y_true_flat) + K.sum(y_pred_flat) - intersection

    # Calculate union: sum of elements in both flattened masks, subtract intersection
    iou = (intersection + 0.0001) / (union + 0.0001)
    return iou

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def iou_loss(y_true, y_pred):
    return 1 - iou(y_true, y_pred)

# %% [markdown]
# ## **Build Model**

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Reshape, UpSampling2D
# from tensorflow.keras import backend as K

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=K.shape(z_mean))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# Fungsi untuk membangun arsitektur 2DVNet
def build_2dvnet(input_shape, latent_dim):
    # Encoder
    input_img = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Flatten()(x)
    z_mean = Dense(latent_dim)(x)
    z_log_var = Dense(latent_dim)(x)
    z = Lambda(sampling)([z_mean, z_log_var])

    # Decoder
    decoder_input = Input(shape=(latent_dim,))
    x = Dense(8*8*64, activation='relu')(decoder_input)
    x = Reshape((8, 8, 64))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    reconstructed_img = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    # Definisikan model
    encoder = Model(input_img, [z_mean, z_log_var, z], name='encoder')
    decoder = Model(decoder_input, reconstructed_img, name='decoder')
    autoencoder = Model(input_img, decoder(encoder(input_img)[2]), name='2DVNet')

    return autoencoder

# %% [markdown]
# ### **Model Compile**

# %%
from tensorflow.keras.optimizers import Adam

# %%
learning_rate = 0.0001  # Set your desired learning rate

# Membuat model menggunakan fungsi vnet_2d
model = vnet_2d((256, 256, 1), filter_num=[16, 32, 64, 128, 256], n_labels=1,
                      res_num_ini=1, res_num_max=3,
                      activation='PReLU', output_activation='Sigmoid',
                      batch_norm=True, pool=False, unpool=False, name='vnet')

# Membuat model menggunakan fungsi vnet_2d
optimizer = Adam(learning_rate=learning_rate)

# Mengompilasi model dengan konfigurasi pengoptimal, fungsi kerugian, dan metrik
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "vnet_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 1)]        0         []
#
#  vnet_input_conv_0 (Conv2D)  (None, 256, 256, 16)         144       ['input_1[0][0]']
#
#  vnet_input_conv_0_bn (Batc  (None, 256, 256, 16)         64        ['vnet_input_conv_0[0][0]']
#  hNormalization)
#
#  vnet_input_conv_0_activati  (None, 256, 256, 16)         1048576   ['vnet_input_conv_0_bn[0][0]']
#  on (PReLU)
#
#  vnet_down_0_0 (Conv2D)      (None, 256, 256, 16)         2304      ['vnet_input_conv_0_activation
#                                                                     [0][0]']
#
#  vnet_down_0_0_bn (BatchNor  (None, 256, 256, 16)         64        ['vnet_down_0_0[0][0]']
#  malization)
#
#  vnet_down_0_0_activation (  (None, 256, 256, 16)         1048576   ['vnet_down_0_0_bn[0][0]']
#  PReLU)
#
#  vnet_down_0_add (Add)       (None, 256, 256, 16)         0         ['vnet_input_conv_0_activation
#                                                                     [0][0]',
#                                                                      'vnet_down_0_0_activation[0][
#                                                                     0]']
#
#  vnet_down_0_add_activation  (None, 256, 256, 16)         1048576   ['vnet_down_0_add[0][0]']
#   (PReLU)
#
#  vnet_down_1_encode_stride_  (None, 128, 128, 32)         2048      ['vnet_down_0_add_activation[0
#  conv (Conv2D)                                                      ][0]']
#
#  vnet_down_1_encode_bn (Bat  (None, 128, 128, 32)         128       ['vnet_down_1_encode_stride_co
#  chNormalization)                                                   nv[0][0]']
#
#  vnet_down_1_encode_activat  (None, 128, 128, 32)         524288    ['vnet_down_1_encode_bn[0][0]'
#  ion (PReLU)                                                        ]
#
#  vnet_down_1_res_conv_0 (Co  (None, 128, 128, 32)         9216      ['vnet_down_1_encode_activatio
#  nv2D)                                                              n[0][0]']
#
#  vnet_down_1_res_conv_0_bn   (None, 128, 128, 32)         128       ['vnet_down_1_res_conv_0[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_1_res_conv_0_act  (None, 128, 128, 32)         524288    ['vnet_down_1_res_conv_0_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_1_res_conv_1 (Co  (None, 128, 128, 32)         9216      ['vnet_down_1_res_conv_0_activ
#  nv2D)                                                              ation[0][0]']
#
#  vnet_down_1_res_conv_1_bn   (None, 128, 128, 32)         128       ['vnet_down_1_res_conv_1[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_1_res_conv_1_act  (None, 128, 128, 32)         524288    ['vnet_down_1_res_conv_1_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_1_res_conv_add (  (None, 128, 128, 32)         0         ['vnet_down_1_encode_activatio
#  Add)                                                               n[0][0]',
#                                                                      'vnet_down_1_res_conv_1_activ
#                                                                     ation[0][0]']
#
#  vnet_down_1_res_conv_add_a  (None, 128, 128, 32)         524288    ['vnet_down_1_res_conv_add[0][
#  ctivation (PReLU)                                                  0]']
#
#  vnet_down_2_encode_stride_  (None, 64, 64, 64)           8192      ['vnet_down_1_res_conv_add_act
#  conv (Conv2D)                                                      ivation[0][0]']
#
#  vnet_down_2_encode_bn (Bat  (None, 64, 64, 64)           256       ['vnet_down_2_encode_stride_co
#  chNormalization)                                                   nv[0][0]']
#
#  vnet_down_2_encode_activat  (None, 64, 64, 64)           262144    ['vnet_down_2_encode_bn[0][0]'
#  ion (PReLU)                                                        ]
#
#  vnet_down_2_res_conv_0 (Co  (None, 64, 64, 64)           36864     ['vnet_down_2_encode_activatio
#  nv2D)                                                              n[0][0]']
#
#  vnet_down_2_res_conv_0_bn   (None, 64, 64, 64)           256       ['vnet_down_2_res_conv_0[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_2_res_conv_0_act  (None, 64, 64, 64)           262144    ['vnet_down_2_res_conv_0_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_2_res_conv_1 (Co  (None, 64, 64, 64)           36864     ['vnet_down_2_res_conv_0_activ
#  nv2D)                                                              ation[0][0]']
#
#  vnet_down_2_res_conv_1_bn   (None, 64, 64, 64)           256       ['vnet_down_2_res_conv_1[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_2_res_conv_1_act  (None, 64, 64, 64)           262144    ['vnet_down_2_res_conv_1_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_2_res_conv_2 (Co  (None, 64, 64, 64)           36864     ['vnet_down_2_res_conv_1_activ
#  nv2D)                                                              ation[0][0]']
#
#  vnet_down_2_res_conv_2_bn   (None, 64, 64, 64)           256       ['vnet_down_2_res_conv_2[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_2_res_conv_2_act  (None, 64, 64, 64)           262144    ['vnet_down_2_res_conv_2_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_2_res_conv_add (  (None, 64, 64, 64)           0         ['vnet_down_2_encode_activatio
#  Add)                                                               n[0][0]',
#                                                                      'vnet_down_2_res_conv_2_activ
#                                                                     ation[0][0]']
#
#  vnet_down_2_res_conv_add_a  (None, 64, 64, 64)           262144    ['vnet_down_2_res_conv_add[0][
#  ctivation (PReLU)                                                  0]']
#
#  vnet_down_3_encode_stride_  (None, 32, 32, 128)          32768     ['vnet_down_2_res_conv_add_act
#  conv (Conv2D)                                                      ivation[0][0]']
#
#  vnet_down_3_encode_bn (Bat  (None, 32, 32, 128)          512       ['vnet_down_3_encode_stride_co
#  chNormalization)                                                   nv[0][0]']
#
#  vnet_down_3_encode_activat  (None, 32, 32, 128)          131072    ['vnet_down_3_encode_bn[0][0]'
#  ion (PReLU)                                                        ]
#
#  vnet_down_3_res_conv_0 (Co  (None, 32, 32, 128)          147456    ['vnet_down_3_encode_activatio
#  nv2D)                                                              n[0][0]']
#
#  vnet_down_3_res_conv_0_bn   (None, 32, 32, 128)          512       ['vnet_down_3_res_conv_0[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_3_res_conv_0_act  (None, 32, 32, 128)          131072    ['vnet_down_3_res_conv_0_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_3_res_conv_1 (Co  (None, 32, 32, 128)          147456    ['vnet_down_3_res_conv_0_activ
#  nv2D)                                                              ation[0][0]']
#
#  vnet_down_3_res_conv_1_bn   (None, 32, 32, 128)          512       ['vnet_down_3_res_conv_1[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_3_res_conv_1_act  (None, 32, 32, 128)          131072    ['vnet_down_3_res_conv_1_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_3_res_conv_2 (Co  (None, 32, 32, 128)          147456    ['vnet_down_3_res_conv_1_activ
#  nv2D)                                                              ation[0][0]']
#
#  vnet_down_3_res_conv_2_bn   (None, 32, 32, 128)          512       ['vnet_down_3_res_conv_2[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_3_res_conv_2_act  (None, 32, 32, 128)          131072    ['vnet_down_3_res_conv_2_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_3_res_conv_add (  (None, 32, 32, 128)          0         ['vnet_down_3_encode_activatio
#  Add)                                                               n[0][0]',
#                                                                      'vnet_down_3_res_conv_2_activ
#                                                                     ation[0][0]']
#
#  vnet_down_3_res_conv_add_a  (None, 32, 32, 128)          131072    ['vnet_down_3_res_conv_add[0][
#  ctivation (PReLU)                                                  0]']
#
#  vnet_down_4_encode_stride_  (None, 16, 16, 256)          131072    ['vnet_down_3_res_conv_add_act
#  conv (Conv2D)                                                      ivation[0][0]']
#
#  vnet_down_4_encode_bn (Bat  (None, 16, 16, 256)          1024      ['vnet_down_4_encode_stride_co
#  chNormalization)                                                   nv[0][0]']
#
#  vnet_down_4_encode_activat  (None, 16, 16, 256)          65536     ['vnet_down_4_encode_bn[0][0]'
#  ion (PReLU)                                                        ]
#
#  vnet_down_4_res_conv_0 (Co  (None, 16, 16, 256)          589824    ['vnet_down_4_encode_activatio
#  nv2D)                                                              n[0][0]']
#
#  vnet_down_4_res_conv_0_bn   (None, 16, 16, 256)          1024      ['vnet_down_4_res_conv_0[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_4_res_conv_0_act  (None, 16, 16, 256)          65536     ['vnet_down_4_res_conv_0_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_4_res_conv_1 (Co  (None, 16, 16, 256)          589824    ['vnet_down_4_res_conv_0_activ
#  nv2D)                                                              ation[0][0]']
#
#  vnet_down_4_res_conv_1_bn   (None, 16, 16, 256)          1024      ['vnet_down_4_res_conv_1[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_4_res_conv_1_act  (None, 16, 16, 256)          65536     ['vnet_down_4_res_conv_1_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_4_res_conv_2 (Co  (None, 16, 16, 256)          589824    ['vnet_down_4_res_conv_1_activ
#  nv2D)                                                              ation[0][0]']
#
#  vnet_down_4_res_conv_2_bn   (None, 16, 16, 256)          1024      ['vnet_down_4_res_conv_2[0][0]
#  (BatchNormalization)                                               ']
#
#  vnet_down_4_res_conv_2_act  (None, 16, 16, 256)          65536     ['vnet_down_4_res_conv_2_bn[0]
#  ivation (PReLU)                                                    [0]']
#
#  vnet_down_4_res_conv_add (  (None, 16, 16, 256)          0         ['vnet_down_4_encode_activatio
#  Add)                                                               n[0][0]',
#                                                                      'vnet_down_4_res_conv_2_activ
#                                                                     ation[0][0]']
#
#  vnet_down_4_res_conv_add_a  (None, 16, 16, 256)          65536     ['vnet_down_4_res_conv_add[0][
#  ctivation (PReLU)                                                  0]']
#
#  vnet_up_0_decode_trans_con  (None, 32, 32, 128)          295040    ['vnet_down_4_res_conv_add_act
#  v (Conv2DTranspose)                                                ivation[0][0]']
#
#  vnet_up_0_decode_bn (Batch  (None, 32, 32, 128)          512       ['vnet_up_0_decode_trans_conv[
#  Normalization)                                                     0][0]']
#
#  vnet_up_0_decode_activatio  (None, 32, 32, 128)          131072    ['vnet_up_0_decode_bn[0][0]']
#  n (PReLU)
#
#  vnet_up_0_concat (Concaten  (None, 32, 32, 256)          0         ['vnet_up_0_decode_activation[
#  ate)                                                               0][0]',
#                                                                      'vnet_down_3_res_conv_add_act
#                                                                     ivation[0][0]']
#
#  vnet_up_0_res_conv_0 (Conv  (None, 32, 32, 128)          294912    ['vnet_up_0_concat[0][0]']
#  2D)
#
#  vnet_up_0_res_conv_0_bn (B  (None, 32, 32, 128)          512       ['vnet_up_0_res_conv_0[0][0]']
#  atchNormalization)
#
#  vnet_up_0_res_conv_0_activ  (None, 32, 32, 128)          131072    ['vnet_up_0_res_conv_0_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_0_res_conv_1 (Conv  (None, 32, 32, 128)          147456    ['vnet_up_0_res_conv_0_activat
#  2D)                                                                ion[0][0]']
#
#  vnet_up_0_res_conv_1_bn (B  (None, 32, 32, 128)          512       ['vnet_up_0_res_conv_1[0][0]']
#  atchNormalization)
#
#  vnet_up_0_res_conv_1_activ  (None, 32, 32, 128)          131072    ['vnet_up_0_res_conv_1_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_0_res_conv_2 (Conv  (None, 32, 32, 128)          147456    ['vnet_up_0_res_conv_1_activat
#  2D)                                                                ion[0][0]']
#
#  vnet_up_0_res_conv_2_bn (B  (None, 32, 32, 128)          512       ['vnet_up_0_res_conv_2[0][0]']
#  atchNormalization)
#
#  vnet_up_0_res_conv_2_activ  (None, 32, 32, 128)          131072    ['vnet_up_0_res_conv_2_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_0_res_conv_add (Ad  (None, 32, 32, 128)          0         ['vnet_up_0_decode_activation[
#  d)                                                                 0][0]',
#                                                                      'vnet_up_0_res_conv_2_activat
#                                                                     ion[0][0]']
#
#  vnet_up_0_res_conv_add_act  (None, 32, 32, 128)          131072    ['vnet_up_0_res_conv_add[0][0]
#  ivation (PReLU)                                                    ']
#
#  vnet_up_1_decode_trans_con  (None, 64, 64, 64)           73792     ['vnet_up_0_res_conv_add_activ
#  v (Conv2DTranspose)                                                ation[0][0]']
#
#  vnet_up_1_decode_bn (Batch  (None, 64, 64, 64)           256       ['vnet_up_1_decode_trans_conv[
#  Normalization)                                                     0][0]']
#
#  vnet_up_1_decode_activatio  (None, 64, 64, 64)           262144    ['vnet_up_1_decode_bn[0][0]']
#  n (PReLU)
#
#  vnet_up_1_concat (Concaten  (None, 64, 64, 128)          0         ['vnet_up_1_decode_activation[
#  ate)                                                               0][0]',
#                                                                      'vnet_down_2_res_conv_add_act
#                                                                     ivation[0][0]']
#
#  vnet_up_1_res_conv_0 (Conv  (None, 64, 64, 64)           73728     ['vnet_up_1_concat[0][0]']
#  2D)
#
#  vnet_up_1_res_conv_0_bn (B  (None, 64, 64, 64)           256       ['vnet_up_1_res_conv_0[0][0]']
#  atchNormalization)
#
#  vnet_up_1_res_conv_0_activ  (None, 64, 64, 64)           262144    ['vnet_up_1_res_conv_0_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_1_res_conv_1 (Conv  (None, 64, 64, 64)           36864     ['vnet_up_1_res_conv_0_activat
#  2D)                                                                ion[0][0]']
#
#  vnet_up_1_res_conv_1_bn (B  (None, 64, 64, 64)           256       ['vnet_up_1_res_conv_1[0][0]']
#  atchNormalization)
#
#  vnet_up_1_res_conv_1_activ  (None, 64, 64, 64)           262144    ['vnet_up_1_res_conv_1_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_1_res_conv_2 (Conv  (None, 64, 64, 64)           36864     ['vnet_up_1_res_conv_1_activat
#  2D)                                                                ion[0][0]']
#
#  vnet_up_1_res_conv_2_bn (B  (None, 64, 64, 64)           256       ['vnet_up_1_res_conv_2[0][0]']
#  atchNormalization)
#
#  vnet_up_1_res_conv_2_activ  (None, 64, 64, 64)           262144    ['vnet_up_1_res_conv_2_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_1_res_conv_add (Ad  (None, 64, 64, 64)           0         ['vnet_up_1_decode_activation[
#  d)                                                                 0][0]',
#                                                                      'vnet_up_1_res_conv_2_activat
#                                                                     ion[0][0]']
#
#  vnet_up_1_res_conv_add_act  (None, 64, 64, 64)           262144    ['vnet_up_1_res_conv_add[0][0]
#  ivation (PReLU)                                                    ']
#
#  vnet_up_2_decode_trans_con  (None, 128, 128, 32)         18464     ['vnet_up_1_res_conv_add_activ
#  v (Conv2DTranspose)                                                ation[0][0]']
#
#  vnet_up_2_decode_bn (Batch  (None, 128, 128, 32)         128       ['vnet_up_2_decode_trans_conv[
#  Normalization)                                                     0][0]']
#
#  vnet_up_2_decode_activatio  (None, 128, 128, 32)         524288    ['vnet_up_2_decode_bn[0][0]']
#  n (PReLU)
#
#  vnet_up_2_concat (Concaten  (None, 128, 128, 64)         0         ['vnet_up_2_decode_activation[
#  ate)                                                               0][0]',
#                                                                      'vnet_down_1_res_conv_add_act
#                                                                     ivation[0][0]']
#
#  vnet_up_2_res_conv_0 (Conv  (None, 128, 128, 32)         18432     ['vnet_up_2_concat[0][0]']
#  2D)
#
#  vnet_up_2_res_conv_0_bn (B  (None, 128, 128, 32)         128       ['vnet_up_2_res_conv_0[0][0]']
#  atchNormalization)
#
#  vnet_up_2_res_conv_0_activ  (None, 128, 128, 32)         524288    ['vnet_up_2_res_conv_0_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_2_res_conv_1 (Conv  (None, 128, 128, 32)         9216      ['vnet_up_2_res_conv_0_activat
#  2D)                                                                ion[0][0]']
#
#  vnet_up_2_res_conv_1_bn (B  (None, 128, 128, 32)         128       ['vnet_up_2_res_conv_1[0][0]']
#  atchNormalization)
#
#  vnet_up_2_res_conv_1_activ  (None, 128, 128, 32)         524288    ['vnet_up_2_res_conv_1_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_2_res_conv_add (Ad  (None, 128, 128, 32)         0         ['vnet_up_2_decode_activation[
#  d)                                                                 0][0]',
#                                                                      'vnet_up_2_res_conv_1_activat
#                                                                     ion[0][0]']
#
#  vnet_up_2_res_conv_add_act  (None, 128, 128, 32)         524288    ['vnet_up_2_res_conv_add[0][0]
#  ivation (PReLU)                                                    ']
#
#  vnet_up_3_decode_trans_con  (None, 256, 256, 16)         4624      ['vnet_up_2_res_conv_add_activ
#  v (Conv2DTranspose)                                                ation[0][0]']
#
#  vnet_up_3_decode_bn (Batch  (None, 256, 256, 16)         64        ['vnet_up_3_decode_trans_conv[
#  Normalization)                                                     0][0]']
#
#  vnet_up_3_decode_activatio  (None, 256, 256, 16)         1048576   ['vnet_up_3_decode_bn[0][0]']
#  n (PReLU)
#
#  vnet_up_3_concat (Concaten  (None, 256, 256, 32)         0         ['vnet_up_3_decode_activation[
#  ate)                                                               0][0]',
#                                                                      'vnet_down_0_add_activation[0
#                                                                     ][0]']
#
#  vnet_up_3_res_conv_0 (Conv  (None, 256, 256, 16)         4608      ['vnet_up_3_concat[0][0]']
#  2D)
#
#  vnet_up_3_res_conv_0_bn (B  (None, 256, 256, 16)         64        ['vnet_up_3_res_conv_0[0][0]']
#  atchNormalization)
#
#  vnet_up_3_res_conv_0_activ  (None, 256, 256, 16)         1048576   ['vnet_up_3_res_conv_0_bn[0][0
#  ation (PReLU)                                                      ]']
#
#  vnet_up_3_res_conv_add (Ad  (None, 256, 256, 16)         0         ['vnet_up_3_decode_activation[
#  d)                                                                 0][0]',
#                                                                      'vnet_up_3_res_conv_0_activat
#                                                                     ion[0][0]']
#
#  vnet_up_3_res_conv_add_act  (None, 256, 256, 16)         1048576   ['vnet_up_3_res_conv_add[0][0]
#  ivation (PReLU)                                                    ']
#
#  vnet_output (Conv2D)        (None, 256, 256, 1)          17        ['vnet_up_3_res_conv_add_activ
#                                                                     ation[0][0]']
#
#  vnet_output_activation (Ac  (None, 256, 256, 1)          0         ['vnet_output[0][0]']
#  tivation)
#
# ==================================================================================================
# Total params: 18435729 (70.33 MB)
# Trainable params: 18430097 (70.31 MB)
# Non-trainable params: 5632 (22.00 KB)
# __________________________________________________________________________________________________

# %%
# Membuat model menggunakan fungsi build_2dvnet
input_shape = (256, 256, 1)  # Bentuk input gambar (misalnya, gambar berukuran 256x256 piksel dengan saluran tunggal)
latent_dim = 32  # Dimensi latent

model = build_2dvnet(input_shape, latent_dim)

# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "2DVNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  encoder (Functional)        [(None, 32),              16796096
#                               (None, 32),
#                               (None, 32)]
#
#  decoder (Functional)        (None, 64, 64, 1)         195329
#
# =================================================================
# Total params: 16991425 (64.82 MB)
# Trainable params: 16991425 (64.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def getArrFromExcel(sheet_name):
    images_arr = []  # List untuk menyimpan array gambar
    masks_arr = []   # List untuk menyimpan array mask
    images_path = pd.read_excel(EXCEL_FILENAME, sheet_name=sheet_name)['images_path']
    masks_path = pd.read_excel(EXCEL_FILENAME, sheet_name=sheet_name)['masks_path']

    # Iterasi melalui setiap baris di lembar excel
    for image_path, mask_path in zip(images_path, masks_path):
        # Memuat array gambar dan masker menggunakan NumPy
        images_arr.append(np.load(image_path))
        masks_arr.append(np.load(mask_path))

        # break # Hapus jika train semua data

    # Mengembalikan array NumPy dari list
    return np.array(images_arr), np.array(masks_arr)

# %%
from timeit import default_timer as timer

class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]

    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()

    def on_epoch_end(self, epoch, logs={}):
        # Menghitung waktu eksekusi dan menambahkannya ke dalam list logs
        self.logs.append(timer()-self.starttime)

# %% [markdown]
# # **Training**

# %%
# Menghitung jumlah lembar (sheet) pada file Excel
n_sheets_excel = len(pd.ExcelFile(EXCEL_FILENAME).sheet_names)
print("Jumlah Lembar (Sheet) pada Excel:", n_sheets_excel)

# Menghitung jumlah k-fold untuk validasi silang
n_k_fold = int((n_sheets_excel - 1) / 2)
print("Jumlah K-Fold untuk Validasi Silang:", n_k_fold)
# Out:
# Jumlah Lembar (Sheet) pada Excel: 11
# Jumlah K-Fold untuk Validasi Silang: 5

# %%
n_sheets_excel = len(pd.ExcelFile(EXCEL_FILENAME).sheet_names)
n_k_fold = int((n_sheets_excel - 1) / 2)

# Drive Path
drive_path = "/content/drive/MyDrive/190411100195-Firman Maulana/2DVNET_EP15/"

for k in range(1, n_k_fold + 1):
    print("##################### FOLD - {} #####################".format(k))

    # CALLBACK
    # CSV Logger Callback
    csv_logger_name = drive_path + 'csv_loggers/csv_logger_fold_{}.csv'.format(k)
    csv_logger_callback = CSVLogger(csv_logger_name)
    # Checkpoint Callback
    checkpoint_name = drive_path + "model_checkpoints/model_fold_{}/ModelCheckpoint-fold{}-".format(k, k) + "{epoch:02d}-{val_dice_coef:.2f}.hdf5"
    checkpoint_callback = ModelCheckpoint(checkpoint_name, save_best_only=True)
    # Timer Callback
    timer_callback = TimingCallback()

    # All Callback
    callback_list = [csv_logger_callback, timer_callback]

    # Sheet Name
    train_sheet_name_per_fold = "fold_{}_train".format(k)
    val_sheet_name_per_fold = "fold_{}_val".format(k)
    # Get Array Images and Masks
    train_images_arr, train_masks_arr = getArrFromExcel(train_sheet_name_per_fold)
    val_images_arr, val_masks_arr = getArrFromExcel(val_sheet_name_per_fold)

    # Build Model
    input_shape = train_images_arr[0].shape
    model = vnet_2d((256, 256, 1), filter_num=[16, 32, 64, 128, 256],
                    n_labels=1,
                      res_num_ini=1, res_num_max=3,
                      activation='PReLU', output_activation='Sigmoid',
                      batch_norm=True, pool=False, unpool=False, name='vnet')

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[iou, dice_coef])


    # Model Training
    history = model.fit(train_images_arr,
                        train_masks_arr,
                        validation_data=(val_images_arr, val_masks_arr),
                        batch_size=16,
                        epochs=15,
                        callbacks=callback_list,
                        verbose=1)  # Set verbose to 1 for printing training progress

    # Extract metrics values from the training history
    # train_loss = history.history['loss'][-1]
    train_iou = history.history['iou'][-1]
    train_dice_coef = history.history['dice_coef'][-1]

    # Print the training metrics with 5 digits after the decimal point
    #print(f"Fold {k} - Train Loss: {train_loss:.5f} - Train Accuracy: {train_accuracy:.5f} - Train IOU: {train_iou:.5f} - Train Dice Coefficient: {train_dice_coef:.5f}")

    # Print the training metrics with 5 digits after the decimal point
    print(f"Fold {k} - Train IOU: {train_iou:.5f} - Train Dice Coefficient: {train_dice_coef:.5f}")

    # Time Computation Per Fold Documentation
    excel_filename = "Training Time Computation Fold - {}.xlsx".format(k)
    time_df = pd.DataFrame({"time_computation_per_epoch":timer_callback.logs})
    with pd.ExcelWriter(drive_path + "time_computation/" + excel_filename) as writer:
        time_df.to_excel(writer)

    # Model Per Fold Documentation
    model.save(drive_path + "model_per_fold/model_fold_{}.h5".format(k))
# Out:
# ##################### FOLD - 1 #####################
# Epoch 1/15
# 68/68 [==============================] - 77s 499ms/step - loss: 0.3968 - iou: 0.3963 - dice_coef: 0.5540 - val_loss: 0.5144 - val_iou: 0.1949 - val_dice_coef: 0.3261
# Epoch 2/15
# 68/68 [==============================] - 23s 346ms/step - loss: 0.1274 - iou: 0.6992 - dice_coef: 0.8220 - val_loss: 0.6854 - val_iou: 0.3642 - val_dice_coef: 0.5337
# Epoch 3/15
# 68/68 [==============================] - 25s 362ms/step - loss: 0.0868 - iou: 0.7824 - dice_coef: 0.8777 - val_loss: 0.5444 - val_iou: 0.3630 - val_dice_coef: 0.5321
# Epoch 4/15
# 68/68 [==============================] - 25s 364ms/step - loss: 0.0695 - iou: 0.8239 - dice_coef: 0.9033 - val_loss: 0.4079 - val_iou: 0.3859 - val_dice_coef: 0.5550
# Epoch 5/15
# 68/68 [==============================] - 24s 359ms/step - loss: 0.0640 - iou: 0.8410 - dice_coef: 0.9134 - val_loss: 0.2158 - val_iou: 0.6133 - val_dice_coef: 0.7599
# Epoch 6/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0494 - iou: 0.8727 - dice_coef: 0.9319 - val_loss: 0.2074 - val_iou: 0.6660 - val_dice_coef: 0.7989
# Epoch 7/15
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0429 - iou: 0.8893 - dice_coef: 0.9413 - val_loss: 0.0699 - val_iou: 0.8479 - val_dice_coef: 0.9175
# Epoch 8/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0363 - iou: 0.9047 - dice_coef: 0.9499 - val_loss: 0.0570 - val_iou: 0.8781 - val_dice_coef: 0.9350
# Epoch 9/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0321 - iou: 0.9155 - dice_coef: 0.9559 - val_loss: 0.0524 - val_iou: 0.8920 - val_dice_coef: 0.9428
# Epoch 10/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0292 - iou: 0.9234 - dice_coef: 0.9602 - val_loss: 0.0483 - val_iou: 0.8932 - val_dice_coef: 0.9435
# Epoch 11/15
# 68/68 [==============================] - 24s 350ms/step - loss: 0.0281 - iou: 0.9263 - dice_coef: 0.9617 - val_loss: 0.0491 - val_iou: 0.9051 - val_dice_coef: 0.9500
# Epoch 12/15
# 68/68 [==============================] - 24s 360ms/step - loss: 0.0263 - iou: 0.9313 - dice_coef: 0.9644 - val_loss: 0.0556 - val_iou: 0.9033 - val_dice_coef: 0.9491
# Epoch 13/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0262 - iou: 0.9321 - dice_coef: 0.9648 - val_loss: 0.0454 - val_iou: 0.9143 - val_dice_coef: 0.9551
# Epoch 14/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0235 - iou: 0.9392 - dice_coef: 0.9686 - val_loss: 0.0489 - val_iou: 0.9145 - val_dice_coef: 0.9552
# Epoch 15/15
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0222 - iou: 0.9415 - dice_coef: 0.9699 - val_loss: 0.0504 - val_iou: 0.9144 - val_dice_coef: 0.9552
# Fold 1 - Train IOU: 0.94150 - Train Dice Coefficient: 0.96986
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ##################### FOLD - 2 #####################
# Epoch 1/15
# 68/68 [==============================] - 45s 373ms/step - loss: 0.2024 - iou: 0.5926 - dice_coef: 0.7277 - val_loss: 0.4757 - val_iou: 0.3360 - val_dice_coef: 0.5028
# Epoch 2/15
# 68/68 [==============================] - 24s 355ms/step - loss: 0.0848 - iou: 0.8010 - dice_coef: 0.8893 - val_loss: 0.3598 - val_iou: 0.5108 - val_dice_coef: 0.6757
# Epoch 3/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0691 - iou: 0.8374 - dice_coef: 0.9113 - val_loss: 0.2447 - val_iou: 0.6269 - val_dice_coef: 0.7702
# Epoch 4/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0532 - iou: 0.8716 - dice_coef: 0.9313 - val_loss: 0.1627 - val_iou: 0.7040 - val_dice_coef: 0.8258
# Epoch 5/15
# 68/68 [==============================] - 25s 362ms/step - loss: 0.0475 - iou: 0.8852 - dice_coef: 0.9390 - val_loss: 0.1357 - val_iou: 0.7647 - val_dice_coef: 0.8662
# Epoch 6/15
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0415 - iou: 0.8991 - dice_coef: 0.9468 - val_loss: 0.1729 - val_iou: 0.7392 - val_dice_coef: 0.8496
# Epoch 7/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0352 - iou: 0.9128 - dice_coef: 0.9544 - val_loss: 0.0883 - val_iou: 0.8546 - val_dice_coef: 0.9214
# Epoch 8/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0311 - iou: 0.9227 - dice_coef: 0.9597 - val_loss: 0.0662 - val_iou: 0.8820 - val_dice_coef: 0.9372
# Epoch 9/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0309 - iou: 0.9231 - dice_coef: 0.9600 - val_loss: 0.0507 - val_iou: 0.9008 - val_dice_coef: 0.9477
# Epoch 10/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0278 - iou: 0.9304 - dice_coef: 0.9639 - val_loss: 0.0515 - val_iou: 0.9051 - val_dice_coef: 0.9502
# Epoch 11/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0246 - iou: 0.9379 - dice_coef: 0.9680 - val_loss: 0.0418 - val_iou: 0.9171 - val_dice_coef: 0.9567
# Epoch 12/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0227 - iou: 0.9422 - dice_coef: 0.9702 - val_loss: 0.0403 - val_iou: 0.9206 - val_dice_coef: 0.9586
# Epoch 13/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0213 - iou: 0.9457 - dice_coef: 0.9721 - val_loss: 0.0417 - val_iou: 0.9220 - val_dice_coef: 0.9594
# Epoch 14/15
# 68/68 [==============================] - 25s 362ms/step - loss: 0.0201 - iou: 0.9486 - dice_coef: 0.9736 - val_loss: 0.0437 - val_iou: 0.9231 - val_dice_coef: 0.9600
# Epoch 15/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0192 - iou: 0.9510 - dice_coef: 0.9749 - val_loss: 0.0502 - val_iou: 0.9251 - val_dice_coef: 0.9611
# Fold 2 - Train IOU: 0.95097 - Train Dice Coefficient: 0.97486
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ##################### FOLD - 3 #####################
# Epoch 1/15
# 68/68 [==============================] - 47s 374ms/step - loss: 0.1978 - iou: 0.6188 - dice_coef: 0.7498 - val_loss: 0.8578 - val_iou: 0.3696 - val_dice_coef: 0.5392
# Epoch 2/15
# 68/68 [==============================] - 24s 355ms/step - loss: 0.0867 - iou: 0.8057 - dice_coef: 0.8920 - val_loss: 0.5751 - val_iou: 0.4825 - val_dice_coef: 0.6504
# Epoch 3/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0643 - iou: 0.8497 - dice_coef: 0.9186 - val_loss: 0.4178 - val_iou: 0.5229 - val_dice_coef: 0.6863
# Epoch 4/15
# 68/68 [==============================] - 24s 360ms/step - loss: 0.0505 - iou: 0.8779 - dice_coef: 0.9349 - val_loss: 0.2124 - val_iou: 0.6440 - val_dice_coef: 0.7828
# Epoch 5/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0489 - iou: 0.8843 - dice_coef: 0.9385 - val_loss: 0.1354 - val_iou: 0.7777 - val_dice_coef: 0.8745
# Epoch 6/15
# 68/68 [==============================] - 24s 350ms/step - loss: 0.0393 - iou: 0.9031 - dice_coef: 0.9490 - val_loss: 0.0876 - val_iou: 0.8250 - val_dice_coef: 0.9039
# Epoch 7/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0330 - iou: 0.9177 - dice_coef: 0.9571 - val_loss: 0.0618 - val_iou: 0.8649 - val_dice_coef: 0.9274
# Epoch 8/15
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0297 - iou: 0.9258 - dice_coef: 0.9614 - val_loss: 0.0717 - val_iou: 0.8679 - val_dice_coef: 0.9291
# Epoch 9/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0265 - iou: 0.9332 - dice_coef: 0.9654 - val_loss: 0.0472 - val_iou: 0.9013 - val_dice_coef: 0.9480
# Epoch 10/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0242 - iou: 0.9384 - dice_coef: 0.9682 - val_loss: 0.0476 - val_iou: 0.9058 - val_dice_coef: 0.9505
# Epoch 11/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0226 - iou: 0.9426 - dice_coef: 0.9704 - val_loss: 0.0487 - val_iou: 0.9076 - val_dice_coef: 0.9515
# Epoch 12/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0293 - iou: 0.9281 - dice_coef: 0.9626 - val_loss: 0.4367 - val_iou: 0.6576 - val_dice_coef: 0.7924
# Epoch 13/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0292 - iou: 0.9276 - dice_coef: 0.9624 - val_loss: 0.0546 - val_iou: 0.8994 - val_dice_coef: 0.9469
# Epoch 14/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0238 - iou: 0.9400 - dice_coef: 0.9690 - val_loss: 0.0533 - val_iou: 0.9094 - val_dice_coef: 0.9525
# Epoch 15/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0205 - iou: 0.9477 - dice_coef: 0.9732 - val_loss: 0.0540 - val_iou: 0.9099 - val_dice_coef: 0.9527
# Fold 3 - Train IOU: 0.94774 - Train Dice Coefficient: 0.97316
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ##################### FOLD - 4 #####################
# Epoch 1/15
# 68/68 [==============================] - 46s 391ms/step - loss: 0.4368 - iou: 0.3605 - dice_coef: 0.5183 - val_loss: 0.6711 - val_iou: 0.2360 - val_dice_coef: 0.3816
# Epoch 2/15
# 68/68 [==============================] - 25s 364ms/step - loss: 0.1561 - iou: 0.6554 - dice_coef: 0.7907 - val_loss: 0.3783 - val_iou: 0.3939 - val_dice_coef: 0.5649
# Epoch 3/15
# 68/68 [==============================] - 24s 359ms/step - loss: 0.1032 - iou: 0.7544 - dice_coef: 0.8596 - val_loss: 0.3073 - val_iou: 0.4587 - val_dice_coef: 0.6285
# Epoch 4/15
# 68/68 [==============================] - 24s 360ms/step - loss: 0.0785 - iou: 0.8079 - dice_coef: 0.8936 - val_loss: 0.3398 - val_iou: 0.4295 - val_dice_coef: 0.6002
# Epoch 5/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0715 - iou: 0.8268 - dice_coef: 0.9050 - val_loss: 0.6362 - val_iou: 0.4978 - val_dice_coef: 0.6642
# Epoch 6/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0560 - iou: 0.8595 - dice_coef: 0.9243 - val_loss: 0.1565 - val_iou: 0.6807 - val_dice_coef: 0.8097
# Epoch 7/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0508 - iou: 0.8736 - dice_coef: 0.9324 - val_loss: 0.0863 - val_iou: 0.8260 - val_dice_coef: 0.9045
# Epoch 8/15
# 68/68 [==============================] - 25s 362ms/step - loss: 0.0431 - iou: 0.8922 - dice_coef: 0.9430 - val_loss: 0.0698 - val_iou: 0.8580 - val_dice_coef: 0.9234
# Epoch 9/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0416 - iou: 0.8960 - dice_coef: 0.9451 - val_loss: 0.0829 - val_iou: 0.8402 - val_dice_coef: 0.9130
# Epoch 10/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0353 - iou: 0.9107 - dice_coef: 0.9532 - val_loss: 0.0730 - val_iou: 0.8656 - val_dice_coef: 0.9278
# Epoch 11/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0328 - iou: 0.9166 - dice_coef: 0.9565 - val_loss: 0.0681 - val_iou: 0.8579 - val_dice_coef: 0.9233
# Epoch 12/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0308 - iou: 0.9220 - dice_coef: 0.9594 - val_loss: 0.0533 - val_iou: 0.8939 - val_dice_coef: 0.9439
# Epoch 13/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0274 - iou: 0.9295 - dice_coef: 0.9634 - val_loss: 0.0434 - val_iou: 0.9137 - val_dice_coef: 0.9548
# Epoch 14/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0242 - iou: 0.9371 - dice_coef: 0.9675 - val_loss: 0.0461 - val_iou: 0.9112 - val_dice_coef: 0.9534
# Epoch 15/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0234 - iou: 0.9398 - dice_coef: 0.9689 - val_loss: 0.0414 - val_iou: 0.9205 - val_dice_coef: 0.9585
# Fold 4 - Train IOU: 0.93975 - Train Dice Coefficient: 0.96893
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ##################### FOLD - 5 #####################
# Epoch 1/15
# 68/68 [==============================] - 46s 383ms/step - loss: 0.2136 - iou: 0.5775 - dice_coef: 0.7146 - val_loss: 1.2037 - val_iou: 0.2692 - val_dice_coef: 0.4239
# Epoch 2/15
# 68/68 [==============================] - 24s 355ms/step - loss: 0.0871 - iou: 0.8027 - dice_coef: 0.8902 - val_loss: 1.2279 - val_iou: 0.3472 - val_dice_coef: 0.5152
# Epoch 3/15
# 68/68 [==============================] - 24s 360ms/step - loss: 0.0662 - iou: 0.8460 - dice_coef: 0.9164 - val_loss: 0.1781 - val_iou: 0.6539 - val_dice_coef: 0.7900
# Epoch 4/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0523 - iou: 0.8739 - dice_coef: 0.9326 - val_loss: 0.1447 - val_iou: 0.7141 - val_dice_coef: 0.8327
# Epoch 5/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0457 - iou: 0.8893 - dice_coef: 0.9414 - val_loss: 0.0994 - val_iou: 0.7815 - val_dice_coef: 0.8769
# Epoch 6/15
# 68/68 [==============================] - 24s 361ms/step - loss: 0.0431 - iou: 0.8965 - dice_coef: 0.9453 - val_loss: 0.2753 - val_iou: 0.6274 - val_dice_coef: 0.7688
# Epoch 7/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0362 - iou: 0.9112 - dice_coef: 0.9535 - val_loss: 0.0636 - val_iou: 0.8799 - val_dice_coef: 0.9359
# Epoch 8/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0330 - iou: 0.9187 - dice_coef: 0.9576 - val_loss: 0.0935 - val_iou: 0.8554 - val_dice_coef: 0.9219
# Epoch 9/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0311 - iou: 0.9221 - dice_coef: 0.9595 - val_loss: 0.0489 - val_iou: 0.9032 - val_dice_coef: 0.9490
# Epoch 10/15
# 68/68 [==============================] - 24s 351ms/step - loss: 0.0263 - iou: 0.9334 - dice_coef: 0.9656 - val_loss: 0.0500 - val_iou: 0.8989 - val_dice_coef: 0.9467
# Epoch 11/15
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0237 - iou: 0.9395 - dice_coef: 0.9688 - val_loss: 0.0430 - val_iou: 0.9124 - val_dice_coef: 0.9541
# Epoch 12/15
# 68/68 [==============================] - 24s 352ms/step - loss: 0.0245 - iou: 0.9386 - dice_coef: 0.9683 - val_loss: 0.1515 - val_iou: 0.8058 - val_dice_coef: 0.8919
# Epoch 13/15
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0344 - iou: 0.9171 - dice_coef: 0.9567 - val_loss: 0.1148 - val_iou: 0.8479 - val_dice_coef: 0.9174
# Epoch 14/15
# 68/68 [==============================] - 25s 362ms/step - loss: 0.0233 - iou: 0.9408 - dice_coef: 0.9695 - val_loss: 0.0426 - val_iou: 0.9198 - val_dice_coef: 0.9582
# Epoch 15/15
# 68/68 [==============================] - 25s 361ms/step - loss: 0.0209 - iou: 0.9465 - dice_coef: 0.9725 - val_loss: 0.0430 - val_iou: 0.9231 - val_dice_coef: 0.9599
# Fold 5 - Train IOU: 0.94650 - Train Dice Coefficient: 0.97251
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # **Evaluate the model**

# %%
from tensorflow.keras.models import load_model
from sklearn.model_selection import KFold

DRIVE_PATH = "/content/drive/MyDrive/190411100195-Firman Maulana/2DVNET_EP15/"
n_folds = 5

# Get the test sheet name
test_sheet_name = "test"

# Get the test images and masks once (assuming they are the same for all folds)
test_images_arr, test_masks_arr = getArrFromExcel(test_sheet_name)

# Initialize variables to track the best fold and its metrics
best_fold = None
best_dice_coef = 0.0  # Assuming higher Dice Coef is better
best_iou = 0.0       # Assuming higher IOU is better

# Perform k-fold cross-validationa
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for fold, (train_index, val_index) in enumerate(kf.split(range(len(test_images_arr)))):
    # Split the data into training and validation sets
    train_images, val_images = test_images_arr[train_index], test_images_arr[val_index]
    train_masks, val_masks = test_masks_arr[train_index], test_masks_arr[val_index]

    # Load the trained model for the current fold
    model_path = DRIVE_PATH + "model_per_fold/model_fold_{}.h5".format(fold + 1)
    model = load_model(model_path, custom_objects={'dice_coef_loss': dice_coef_loss, 'iou_loss': iou_loss,
                                                   'dice_coef': dice_coef, 'iou': iou})

    # Evaluate the model on the validation data for the current fold
    evaluation = model.evaluate(val_images, val_masks)

    # Print the evaluation metrics for the current fold
    print("\nFold {}: ".format(fold + 1))
    print("Validation IOU: {:.5f}".format(evaluation[1]))
    print("Validation Dice Coefficient: {:.5f}".format(evaluation[2]))

    # Update the best fold if the current fold has a higher Dice Coef
    if evaluation[2] > best_dice_coef:
        best_fold = fold + 1
        best_dice_coef = evaluation[2]
        best_iou = evaluation[1]
# Out:
# 1/1 [==============================] - 6s 6s/step - loss: 0.0589 - iou: 0.9005 - dice_coef: 0.9477
#
# Fold 1:
# Validation IOU: 0.90051
# Validation Dice Coefficient: 0.94765
# 1/1 [==============================] - 1s 1s/step - loss: 0.0510 - iou: 0.9243 - dice_coef: 0.9606
#
# Fold 2:
# Validation IOU: 0.92426
# Validation Dice Coefficient: 0.96064
# 1/1 [==============================] - 1s 1s/step - loss: 0.0702 - iou: 0.8925 - dice_coef: 0.9432
#
# Fold 3:
# Validation IOU: 0.89252
# Validation Dice Coefficient: 0.94321
# WARNING:tensorflow:5 out of the last 259 calls to <function Model.make_test_function.<locals>.test_function at 0x7d6ef3982b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step - loss: 0.0540 - iou: 0.9168 - dice_coef: 0.9566
#
# Fold 4:
# Validation IOU: 0.91682
# Validation Dice Coefficient: 0.95661
# WARNING:tensorflow:6 out of the last 260 calls to <function Model.make_test_function.<locals>.test_function at 0x7d6ef380c700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step - loss: 0.0311 - iou: 0.9365 - dice_coef: 0.9672
#
# Fold 5:
# Validation IOU: 0.93653
# Validation Dice Coefficient: 0.96723

# %%
# Print the results of the best fold
print("\nBest Fold: {}".format(best_fold))
print("Best Validation IOU: {:.5f}".format(best_iou))
print("Best Validation Dice Coefficient: {:.5f}".format(best_dice_coef))
# Out:
# Best Fold: 5
# Best Validation IOU: 0.93653
# Best Validation Dice Coefficient: 0.96723

# %% [markdown]
# # **Testing**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Prediksi menggunakan model
pred_candidates = np.random.randint(1, test_images_arr.shape[0], 10)
preds = model.predict(test_images_arr)

plt.figure(figsize=(20, 10))

for i in range(0, 9, 3):
    plt.subplot(3, 3, i + 1)
    plt.title("Base Image")
    plt.imshow(np.squeeze(test_images_arr[pred_candidates[i]]), cmap='gray')
    plt.axis('off')

    plt.subplot(3, 3, i + 2)
    plt.title("Mask")
    plt.imshow(np.squeeze(test_masks_arr[pred_candidates[i]]), cmap='gray')
    plt.axis('off')

    plt.subplot(3, 3, i + 3)
    plt.title("Prediction")
    # Menggabungkan base image dengan mask
    base_image = np.squeeze(test_images_arr[pred_candidates[i]])
    mask = np.squeeze(test_masks_arr[pred_candidates[i]])
    prediction = np.squeeze(preds[pred_candidates[i]])

    # Filter hasil prediksi dengan mask
    masked_prediction = np.where(mask > 0.5, base_image, prediction)

    plt.imshow(masked_prediction, cmap='gray')
    plt.axis('off')

plt.show()
# Out:
# 5/5 [==============================] - 11s 1s/step
